# %%
# %sql
select *
from hive_metastore.framework_testes.test_out_results_details
order by TIMESTAMP desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DETAILS_ID</th><th>RESULT_ID</th><th>KEY_FIELDS</th><th>TIMESTAMP</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select *
from hive_metastore.framework_testes.test_out_results
order by TIMESTAMP desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>RESULT_ID</th><th>TEST_ID</th><th>QUERY</th><th>RESULT</th><th>PARTITION_FILTER_VALUE</th><th>TIMESTAMP</th></tr></thead><tbody><tr><td>17</td><td>17</td><td>
#         SELECT
#             CASE
#                 WHEN (SELECT COUNT(1) FROM joaopereira.premier_league_data_2022 WHERE clube=''Sporting'') =
#                      (SELECT COUNT(1) FROM matildeantao.premier_league_data_2022 WHERE clube=''Sporting'')
#                 THEN ''OK''
#                 ELSE ''NOK''
#             END AS RESULT
# ...

# %%
# %sql
select * from hive_metastore.framework_testes.test_config_parameters;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
UPDATE hive_metastore.framework_testes.test_config_parameters
SET DEST_TABLE = REPLACE(DEST_TABLE, 'iliyan', 'matildeantao')
WHERE DEST_TABLE LIKE '%iliyan%';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>8</td></tr></tbody></table></div>

# %%
# %sql
select *
from hive_metastore.framework_testes.test_rel_set_parameter;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SET_ID</th><th>TEST_ID</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
insert into  hive_metastore.framework_testes.test_rel_set_parameter values(1,1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
truncate table hive_metastore.framework_testes.test_out_results_details;
truncate table hive_metastore.framework_testes.test_out_results;
